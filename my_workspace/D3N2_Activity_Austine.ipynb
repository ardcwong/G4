# %% [markdown]
# # Activity: Trying out your own RFM Analysis

# %% [markdown]
# Replicate the RFM analysis steps, but only for hours 12PM-5PM.
#
# Kindly fill the code cells with python lines to accomplish the tasks. You may refer to the lecture notebook.

# %%
# Import libraries
import pandas as pd

# %%
# Mount GDrive's folders
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# This code imports a library "os" that allows file navigation
import os
# This code sets the home directory
# Find your folder and put the path here as a string
os.chdir('/content/drive/MyDrive/my_workspace')

# %% [markdown]
# ## Prepare data

# %% [markdown]
# Read csv

# %%
df = pd.read_csv("Data/cc_clean.csv")
df.head()
# Out:
#          cc_num gender          city  city_pop  \
# 0  6.760000e+11      M    Dasmarinas    659019
# 1  3.520000e+15      M         Digos    169393
# 2  4.140000e+18      M       Calapan    133893
# 3  4.870000e+15      M  San Fernando    121812
# 4  4.720000e+15      M         Laoag    111125
#
#                                                 job         dob      acct_num  \
# 0                           Chartered loss adjuster  12/12/1958  798000000000
# 1  Administrator, charities/voluntary organisations  31/08/1970  968000000000
# 2                              Financial controller  23/07/1953  628000000000
# 3                                               NaN  18/07/1964  863000000000
# 4                    Dance movement psychotherapist  11/01/1954  257000000000
#
#       acct_num2                         trans_num   unix_time       category  \
# 0  798000000000  a72eaa86b043eed95b25bbb25b3153a1  1581314011   shopping_net
# 1  968000000000  060d12f91c13871a13963041736a4702  1590902968  entertainment
# 2  628000000000  18aafb6098ab0923886c0ac83592ef8d  1585461157    food_dining
# 3  863000000000  45bbe714e51ab8a375454d39a190b0cb  1613063704    food_dining
# 4  257000000000  c20ee88b451f637bc6893b7460e9fee0  1601282159  gas_transport
#
#       amt       trans_datetime
# 0   68.88  2020-02-10 13:53:31
# 1   50.06  2020-05-31 13:29:28
# 2  105.44  2020-03-29 13:52:37
# 3   38.61  2021-02-12 01:15:04
# 4   82.69  2020-09-28 16:35:59

# %%
df['gender'][df['acct_num']==581000000000].count()
# Out:
# 2157

# %%
two_genders = df[df['acct_num']==581000000000]
two_genders = two_genders.groupby(['acct_num', 'gender'])['amt'].count().to_frame(name='count_amt').reset_index()
two_genders
# Out:
#        acct_num gender  count_amt
# 0  581000000000      F         31
# 1  581000000000      M       2126

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   cc_num          100000 non-null  float64
#  1   gender          100000 non-null  object
#  2   city            100000 non-null  object
#  3   city_pop        100000 non-null  int64
#  4   job             92432 non-null   object
#  5   dob             100000 non-null  object
#  6   acct_num        100000 non-null  int64
#  7   acct_num2       100000 non-null  int64
#  8   trans_num       100000 non-null  object
#  9   unix_time       100000 non-null  int64
#  10  category        92392 non-null   object
#  11  amt             100000 non-null  float64
#  12  trans_datetime  100000 non-null  object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 9.9+ MB

# %%
df
# Out:
#              cc_num gender             city  city_pop  \
# 0      6.760000e+11      M       Dasmarinas    659019
# 1      3.520000e+15      M            Digos    169393
# 2      4.140000e+18      M          Calapan    133893
# 3      4.870000e+15      M     San Fernando    121812
# 4      4.720000e+15      M            Laoag    111125
# ...             ...    ...              ...       ...
# 99995  2.470000e+15      M     San Fernando    306659
# 99996  3.520000e+15      M          Masbate     95389
# 99997  4.620000e+15      M     San Fernando    121812
# 99998  4.430000e+15      M   General Santos    594446
# 99999  3.800000e+13      M  City of Isabela    112788
#
#                                                     job         dob  \
# 0                               Chartered loss adjuster  12/12/1958
# 1      Administrator, charities/voluntary organisations  31/08/1970
# 2                                  Financial controller  23/07/1953
# 3                                                   NaN  18/07/1964
# 4                        Dance movement psychotherapist  11/01/1954
# ...                                                 ...         ...
# 99995                                Surveyor, quantity  01/11/1935
# 99996                                Wellsite geologist  20/11/1967
# 99997                                 Personnel officer  20/11/1934
# 99998                                               NaN  26/06/1960
# 99999                   Sport and exercise psychologist  04/03/1967
#
#            acct_num     acct_num2                         trans_num  \
# 0      798000000000  798000000000  a72eaa86b043eed95b25bbb25b3153a1
# 1      968000000000  968000000000  060d12f91c13871a13963041736a4702
# 2      628000000000  628000000000  18aafb6098ab0923886c0ac83592ef8d
# 3      863000000000  863000000000  45bbe714e51ab8a375454d39a190b0cb
# 4      257000000000  257000000000  c20ee88b451f637bc6893b7460e9fee0
# ...             ...           ...                               ...
# 99995  581000000000  581000000000  d44f411eabd406a76a60546e723a98fd
# 99996  531000000000  531000000000  7e767a74cae901c13f1a9d1d37aa63d4
# 99997  555000000000  555000000000  6ced184c93e66028e8d235ad3060de90
# 99998  319000000000  319000000000  599d3eec9b385473aa3791b620691416
# 99999  378000000000  378000000000  67f47400873e964e10e029050dbe1fee
#
#         unix_time       category     amt       trans_datetime
# 0      1581314011   shopping_net   68.88  2020-02-10 13:53:31
# 1      1590902968  entertainment   50.06  2020-05-31 13:29:28
# 2      1585461157    food_dining  105.44  2020-03-29 13:52:37
# 3      1613063704    food_dining   38.61  2021-02-12 01:15:04
# 4      1601282159  gas_transport   82.69  2020-09-28 16:35:59
# ...           ...            ...     ...                  ...
# 99995  1628185569      kids_pets   98.23  2021-08-06 01:46:09
# 99996  1621481285    grocery_pos   78.79  2021-05-20 11:28:05
# 99997  1625341374  personal_care   31.37  2021-07-04 03:42:54
# 99998  1636919758           home   74.76  2021-11-15 03:55:58
# 99999  1605863062   shopping_pos    3.27  2020-11-20 17:04:22
#
# [100000 rows x 13 columns]

# %% [markdown]
# *Trick*: Pandas has its own methods for dates. We just need to convert it using `pd.to_datetime`.

# %%
df['trans_datetime'] = pd.to_datetime(df['trans_datetime'])
df.head()
# Out:
#          cc_num gender          city  city_pop  \
# 0  6.760000e+11      M    Dasmarinas    659019
# 1  3.520000e+15      M         Digos    169393
# 2  4.140000e+18      M       Calapan    133893
# 3  4.870000e+15      M  San Fernando    121812
# 4  4.720000e+15      M         Laoag    111125
#
#                                                 job         dob      acct_num  \
# 0                           Chartered loss adjuster  12/12/1958  798000000000
# 1  Administrator, charities/voluntary organisations  31/08/1970  968000000000
# 2                              Financial controller  23/07/1953  628000000000
# 3                                               NaN  18/07/1964  863000000000
# 4                    Dance movement psychotherapist  11/01/1954  257000000000
#
#       acct_num2                         trans_num   unix_time       category  \
# 0  798000000000  a72eaa86b043eed95b25bbb25b3153a1  1581314011   shopping_net
# 1  968000000000  060d12f91c13871a13963041736a4702  1590902968  entertainment
# 2  628000000000  18aafb6098ab0923886c0ac83592ef8d  1585461157    food_dining
# 3  863000000000  45bbe714e51ab8a375454d39a190b0cb  1613063704    food_dining
# 4  257000000000  c20ee88b451f637bc6893b7460e9fee0  1601282159  gas_transport
#
#       amt      trans_datetime
# 0   68.88 2020-02-10 13:53:31
# 1   50.06 2020-05-31 13:29:28
# 2  105.44 2020-03-29 13:52:37
# 3   38.61 2021-02-12 01:15:04
# 4   82.69 2020-09-28 16:35:59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   cc_num          100000 non-null  float64
#  1   gender          100000 non-null  object
#  2   city            100000 non-null  object
#  3   city_pop        100000 non-null  int64
#  4   job             92432 non-null   object
#  5   dob             100000 non-null  object
#  6   acct_num        100000 non-null  int64
#  7   acct_num2       100000 non-null  int64
#  8   trans_num       100000 non-null  object
#  9   unix_time       100000 non-null  int64
#  10  category        92392 non-null   object
#  11  amt             100000 non-null  float64
#  12  trans_datetime  100000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(4), object(6)
# memory usage: 9.9+ MB

# %% [markdown]
# For recency analysis, we need to know how much days have passed since the transaction, assuming current date is Jan 1, 2022.

# %%
# Define the current date
current_date = pd.to_datetime('2022-01-01')

# Calculate the elapsed days
df['elapsed_days'] = (current_date - df['trans_datetime']).dt.days

# %%
df.head()
# Out:
#          cc_num gender          city  city_pop  \
# 0  6.760000e+11      M    Dasmarinas    659019
# 1  3.520000e+15      M         Digos    169393
# 2  4.140000e+18      M       Calapan    133893
# 3  4.870000e+15      M  San Fernando    121812
# 4  4.720000e+15      M         Laoag    111125
#
#                                                 job         dob      acct_num  \
# 0                           Chartered loss adjuster  12/12/1958  798000000000
# 1  Administrator, charities/voluntary organisations  31/08/1970  968000000000
# 2                              Financial controller  23/07/1953  628000000000
# 3                                               NaN  18/07/1964  863000000000
# 4                    Dance movement psychotherapist  11/01/1954  257000000000
#
#       acct_num2                         trans_num   unix_time       category  \
# 0  798000000000  a72eaa86b043eed95b25bbb25b3153a1  1581314011   shopping_net
# 1  968000000000  060d12f91c13871a13963041736a4702  1590902968  entertainment
# 2  628000000000  18aafb6098ab0923886c0ac83592ef8d  1585461157    food_dining
# 3  863000000000  45bbe714e51ab8a375454d39a190b0cb  1613063704    food_dining
# 4  257000000000  c20ee88b451f637bc6893b7460e9fee0  1601282159  gas_transport
#
#       amt      trans_datetime  elapsed_days
# 0   68.88 2020-02-10 13:53:31           690
# 1   50.06 2020-05-31 13:29:28           579
# 2  105.44 2020-03-29 13:52:37           642
# 3   38.61 2021-02-12 01:15:04           322
# 4   82.69 2020-09-28 16:35:59           459

# %% [markdown]
# # Filter data to only contain transactions done between 12PM-5PM
#
# I invite beginner coders to examine the syntax on how this is done.

# %%
df = df[df['trans_datetime'].dt.hour.between(12, 17)]
df
# Out:
#              cc_num gender               city  city_pop  \
# 0      6.760000e+11      M         Dasmarinas    659019
# 1      3.520000e+15      M              Digos    169393
# 2      4.140000e+18      M            Calapan    133893
# 4      4.720000e+15      M              Laoag    111125
# 5      3.530000e+15      M  City of Paranaque    665822
# ...             ...    ...                ...       ...
# 99981  5.700000e+11      M        Makati City    582602
# 99985  3.890000e+13      M       San Fernando    121812
# 99989  4.140000e+18      M            Calapan    133893
# 99994  3.530000e+15      M         Dasmarinas    659019
# 99999  3.800000e+13      M    City of Isabela    112788
#
#                                                     job         dob  \
# 0                               Chartered loss adjuster  12/12/1958
# 1      Administrator, charities/voluntary organisations  31/08/1970
# 2                                  Financial controller  23/07/1953
# 4                        Dance movement psychotherapist  11/01/1954
# 5                                       Engineer, water  31/07/1961
# ...                                                 ...         ...
# 99981                Surveyor, planning and development  26/07/1957
# 99985                Public relations account executive  04/03/1951
# 99989                              Financial controller  23/07/1953
# 99994                                Physicist, medical  26/03/1965
# 99999                   Sport and exercise psychologist  04/03/1967
#
#            acct_num     acct_num2                         trans_num  \
# 0      798000000000  798000000000  a72eaa86b043eed95b25bbb25b3153a1
# 1      968000000000  968000000000  060d12f91c13871a13963041736a4702
# 2      628000000000  628000000000  18aafb6098ab0923886c0ac83592ef8d
# 4      257000000000  257000000000  c20ee88b451f637bc6893b7460e9fee0
# 5      540000000000  540000000000  b389cc449c9c298e8c004024449f7a27
# ...             ...           ...                               ...
# 99981  902000000000  902000000000  a52f3be218429259c02aacd72e9c4f3d
# 99985  845000000000  845000000000  0b911bc5ee31c447c764ca757ab51ec3
# 99989  628000000000  628000000000  ecef4228fe1b2144e3e986c723a0e62b
# 99994  201000000000  201000000000  4f77498d91283c4910a636b2e8149dda
# 99999  378000000000  378000000000  67f47400873e964e10e029050dbe1fee
#
#         unix_time       category     amt      trans_datetime  elapsed_days
# 0      1581314011   shopping_net   68.88 2020-02-10 13:53:31           690
# 1      1590902968  entertainment   50.06 2020-05-31 13:29:28           579
# 2      1585461157    food_dining  105.44 2020-03-29 13:52:37           642
# 4      1601282159  gas_transport   82.69 2020-09-28 16:35:59           459
# 5      1594960430   shopping_net  363.49 2020-07-17 12:33:50           532
# ...           ...            ...     ...                 ...           ...
# 99981  1622960399   shopping_pos    4.84 2021-06-06 14:19:59           208
# 99985  1630828543       misc_pos   16.36 2021-09-05 15:55:43           117
# 99989  1624768341    grocery_pos  123.35 2021-06-27 12:32:21           187
# 99994  1587273415       misc_pos    6.54 2020-04-19 13:16:55           621
# 99999  1605863062   shopping_pos    3.27 2020-11-20 17:04:22           406
#
# [29906 rows x 14 columns]

# %%
len(df)
# Out:
# 29906

# %% [markdown]
# ## RFM Example
# Determine some spending characteristics of each customer in the past 12 months

# %% [markdown]
# First, create a per-customer table using transactions done in 2021

# %%
# Filter data to 2021
data_df = df[df['trans_datetime'].dt.year==2021]
data_df
# Out:
#              cc_num gender          city  city_pop  \
# 9      4.010000e+12      M    Malaybalay    174625
# 20     4.720000e+15      M         Laoag    111125
# 24     1.800000e+14      M  San Fernando    306659
# 40     1.800000e+14      M       Balanga     96061
# 43     6.550000e+15      M    Malaybalay    174625
# ...             ...    ...           ...       ...
# 99969  4.140000e+18      M       Calapan    133893
# 99980  4.010000e+12      M    Malaybalay    174625
# 99981  5.700000e+11      M   Makati City    582602
# 99985  3.890000e+13      M  San Fernando    121812
# 99989  4.140000e+18      M       Calapan    133893
#
#                                          job         dob      acct_num  \
# 9         Tourist information centre manager  11/01/1966  439000000000
# 20            Dance movement psychotherapist  11/01/1954  257000000000
# 24                          Engineer, mining  09/11/1930  939000000000
# 40            Manufacturing systems engineer  14/05/1950  233000000000
# 43     English as a foreign language teacher  31/12/1948  581000000000
# ...                                      ...         ...           ...
# 99969                   Financial controller  23/07/1953  628000000000
# 99980     Tourist information centre manager  11/01/1966  439000000000
# 99981     Surveyor, planning and development  26/07/1957  902000000000
# 99985     Public relations account executive  04/03/1951  845000000000
# 99989                   Financial controller  23/07/1953  628000000000
#
#           acct_num2                         trans_num   unix_time  \
# 9      439000000000  2ecae6c920f6ae3e3cf3dd3abd225fda  1621672603
# 20     257000000000  78a4d43165c7197ff89304b21fdbdddc  1615625022
# 24     939000000000  dbae67fe8c9b43fc0d4422aeae8d04e4  1632118274
# 40     233000000000  0ea859c92c21479633c2974cbe57b46f  1617774484
# 43     581000000000  fdfabbc8b60f0d5dca51f502d2fdf9c3  1627706423
# ...             ...                               ...         ...
# 99969  628000000000  ac8f4f26ae831bcb7f1a753dbc224677  1623565298
# 99980  439000000000  04220fa6aaa33211f4d1fca354675660  1616223466
# 99981  902000000000  a52f3be218429259c02aacd72e9c4f3d  1622960399
# 99985  845000000000  0b911bc5ee31c447c764ca757ab51ec3  1630828543
# 99989  628000000000  ecef4228fe1b2144e3e986c723a0e62b  1624768341
#
#             category     amt      trans_datetime  elapsed_days
# 9                NaN  114.37 2021-05-22 16:36:43           223
# 20       grocery_pos   67.35 2021-03-13 16:43:42           293
# 24      shopping_net    5.86 2021-09-20 14:11:14           102
# 40     entertainment   59.19 2021-04-07 13:48:04           268
# 43          misc_pos    4.92 2021-07-31 12:40:23           153
# ...              ...     ...                 ...           ...
# 99969  gas_transport   76.50 2021-06-13 14:21:38           201
# 99980   shopping_pos    1.59 2021-03-20 14:57:46           286
# 99981   shopping_pos    4.84 2021-06-06 14:19:59           208
# 99985       misc_pos   16.36 2021-09-05 15:55:43           117
# 99989    grocery_pos  123.35 2021-06-27 12:32:21           187
#
# [14018 rows x 14 columns]

# %% [markdown]
# ### Recency

# %%
# Get days since last transaction of each customer first, and include gender tag
# last transaction min of elapsed time
# groupby + trick to convert back to dataframe
rec_df = data_df.groupby(['acct_num'])['elapsed_days'].min().to_frame(name='recency').reset_index()
rec_df
# Out:
#         acct_num  recency
# 0     3843260959       26
# 1    20386303916      113
# 2    34614744133       28
# 3    38399733986       25
# 4    99645822249       26
# ..           ...      ...
# 69  968000000000       26
# 70  969000000000       26
# 71  971000000000       25
# 72  989000000000       27
# 73  994000000000       25
#
# [74 rows x 2 columns]

# %%
# Get days since last transaction of each customer first, and include gender tag
# last transaction min of elapsed time
# groupby + trick to convert back to dataframe
rec_df = data_df.groupby(['acct_num','gender'])['elapsed_days'].min().to_frame(name='recency').reset_index()
rec_df
# Out:
#         acct_num gender  recency
# 0     3843260959      M       26
# 1    20386303916      M      113
# 2    34614744133      M       28
# 3    38399733986      M       25
# 4    99645822249      M       26
# ..           ...    ...      ...
# 70  968000000000      M       26
# 71  969000000000      M       26
# 72  971000000000      M       25
# 73  989000000000      M       27
# 74  994000000000      F       25
#
# [75 rows x 3 columns]

# %%
two_genders = data_df.groupby(['acct_num','gender'])['elapsed_days'].min().to_frame(name='recency').reset_index()
two_genders = two_genders[two_genders['acct_num']==581000000000]
two_genders
# Out:
#         acct_num gender  recency
# 40  581000000000      F      107
# 41  581000000000      M       25

# %%
rec_df[rec_df['acct_num'].duplicated()]
# Out:
#         acct_num gender  recency
# 41  581000000000      M       25

# %%
rec_df[rec_df['acct_num']==581000000000]
# Out:
#         acct_num gender  recency
# 40  581000000000      F      107
# 41  581000000000      M       25

# %% [markdown]
# Using this, create a system to assign a recency score to the `recency` column.
#
# **More recent transaction => Higher score**
#
# * 1 - low score
# * 2 - medium score
# * 3 - high score

# %%
def assign_score_recency(x):
  if x<=30: # last transaction is within last month
    return 3
  elif 30<x<90: # within last quarter
    return 2
  else: #older than last quarter
    return 1

# %%
rec_df['recency_score'] = rec_df['recency'].map(assign_score_recency)
rec_df
# Out:
#         acct_num gender  recency  recency_score
# 0     3843260959      M       26              3
# 1    20386303916      M      113              1
# 2    34614744133      M       28              3
# 3    38399733986      M       25              3
# 4    99645822249      M       26              3
# ..           ...    ...      ...            ...
# 70  968000000000      M       26              3
# 71  969000000000      M       26              3
# 72  971000000000      M       25              3
# 73  989000000000      M       27              3
# 74  994000000000      F       25              3
#
# [75 rows x 4 columns]

# %% [markdown]
# ### Frequency
# >Q: On average, how frequent did each customer  transact in the past year?

# %%
# Get transaction frequency of each customer first
# groupby + trick to convert back to dataframe
freq_df = data_df.groupby(['acct_num','gender']).size().to_frame(name='frequency').reset_index()
freq_df
# Out:
#         acct_num gender  frequency
# 0     3843260959      M        294
# 1    20386303916      M          1
# 2    34614744133      M        101
# 3    38399733986      M        104
# 4    99645822249      M        321
# ..           ...    ...        ...
# 70  968000000000      M        295
# 71  969000000000      M         93
# 72  971000000000      M        323
# 73  989000000000      M         91
# 74  994000000000      F        196
#
# [75 rows x 3 columns]

# %% [markdown]
# Using pandas method `pd.qcut` (quantile cut), classify and score the customers based on their frequency
#
# **More frequent transactions => Higher score**
#
# * 1- low score
# * 2- medium score
# * 3- high score

# %%
freq_df['frequency'].describe()
# Out:
# count     75.000000
# mean     186.906667
# std      122.446808
# min        1.000000
# 25%       97.000000
# 50%      193.000000
# 75%      289.500000
# max      618.000000
# Name: frequency, dtype: float64

# %%
freq_df['frequency_score'] = pd.qcut(freq_df['frequency'], q=3, labels=[1, 2, 3]).astype(int)
freq_df
# Out:
#         acct_num gender  frequency  frequency_score
# 0     3843260959      M        294                3
# 1    20386303916      M          1                1
# 2    34614744133      M        101                1
# 3    38399733986      M        104                2
# 4    99645822249      M        321                3
# ..           ...    ...        ...              ...
# 70  968000000000      M        295                3
# 71  969000000000      M         93                1
# 72  971000000000      M        323                3
# 73  989000000000      M         91                1
# 74  994000000000      F        196                2
#
# [75 rows x 4 columns]

# %%
freq_df['frequency_score'].value_counts()
# Out:
# frequency_score
# 3    25
# 1    25
# 2    25
# Name: count, dtype: int64

# %% [markdown]
# ### Monetary value
# >Q: On average, how much is the total spending of each customer per gender?

# %%
# Get total spending of each customer first
# groupby + trick to convert back to dataframe
mv_df = data_df.groupby(['acct_num','gender'])['amt'].sum().to_frame(name='total_amt').reset_index()
mv_df
# Out:
#         acct_num gender  total_amt
# 0     3843260959      M   20761.41
# 1    20386303916      M       7.02
# 2    34614744133      M    6368.18
# 3    38399733986      M    7226.88
# 4    99645822249      M   24010.44
# ..           ...    ...        ...
# 70  968000000000      M   19607.37
# 71  969000000000      M    6397.00
# 72  971000000000      M   22261.33
# 73  989000000000      M    7763.82
# 74  994000000000      F   12319.76
#
# [75 rows x 3 columns]

# %% [markdown]
# Using pandas method `pd.qcut` (quantile cut), classify and score the customers based on their monetary value
#
# **Larger total transaction amts => Higher score**
#
# * 1- low score
# * 2- medium score
# * 3- high score

# %%
mv_df['monetary_score'] = pd.qcut(mv_df['total_amt'], q=3, labels=[1, 2, 3]).astype(int)
mv_df
# Out:
#         acct_num gender  total_amt  monetary_score
# 0     3843260959      M   20761.41               3
# 1    20386303916      M       7.02               1
# 2    34614744133      M    6368.18               1
# 3    38399733986      M    7226.88               2
# 4    99645822249      M   24010.44               3
# ..           ...    ...        ...             ...
# 70  968000000000      M   19607.37               3
# 71  969000000000      M    6397.00               1
# 72  971000000000      M   22261.33               3
# 73  989000000000      M    7763.82               2
# 74  994000000000      F   12319.76               2
#
# [75 rows x 4 columns]

# %% [markdown]
# ### Total RFM score
# To compute the total score, we need to
#
#
# 1.   Merge the recency, frequency, and monetary value tables together
# 2.   Add the scores to a column `rfm_score`

# %%
mv_df
# Out:
#         acct_num gender  total_amt  monetary_score
# 0     3843260959      M   20761.41               3
# 1    20386303916      M       7.02               1
# 2    34614744133      M    6368.18               1
# 3    38399733986      M    7226.88               2
# 4    99645822249      M   24010.44               3
# ..           ...    ...        ...             ...
# 70  968000000000      M   19607.37               3
# 71  969000000000      M    6397.00               1
# 72  971000000000      M   22261.33               3
# 73  989000000000      M    7763.82               2
# 74  994000000000      F   12319.76               2
#
# [75 rows x 4 columns]

# %%
# First, merge rec_df and freq_df using pd.merge
rfm_df = pd.merge(rec_df, freq_df, on=['acct_num','gender'], how='inner')
rfm_df
# Out:
#         acct_num gender  recency  recency_score  frequency  frequency_score
# 0     3843260959      M       26              3        294                3
# 1    20386303916      M      113              1          1                1
# 2    34614744133      M       28              3        101                1
# 3    38399733986      M       25              3        104                2
# 4    99645822249      M       26              3        321                3
# ..           ...    ...      ...            ...        ...              ...
# 70  968000000000      M       26              3        295                3
# 71  969000000000      M       26              3         93                1
# 72  971000000000      M       25              3        323                3
# 73  989000000000      M       27              3         91                1
# 74  994000000000      F       25              3        196                2
#
# [75 rows x 6 columns]

# %%
print(len(rec_df))
print(len(freq_df))
print(len(rfm_df))
# Out:
# 75
# 75
# 75

# %% [markdown]
# Add up the scores and store in column `rfm_score`

# %%
rfm_df = pd.merge(rfm_df, mv_df, on=['acct_num','gender'], how='inner')
rfm_df.head()
# Out:
#       acct_num gender  recency  recency_score  frequency  frequency_score  \
# 0   3843260959      M       26              3        294                3
# 1  20386303916      M      113              1          1                1
# 2  34614744133      M       28              3        101                1
# 3  38399733986      M       25              3        104                2
# 4  99645822249      M       26              3        321                3
#
#    total_amt  monetary_score
# 0   20761.41               3
# 1       7.02               1
# 2    6368.18               1
# 3    7226.88               2
# 4   24010.44               3

# %%
rfm_df['rfm_score'] = rfm_df['recency_score'] + rfm_df['frequency_score'] +rfm_df['monetary_score']

# %%
rfm_df['rfm_score'].value_counts()
# Out:
# rfm_score
# 9    24
# 7    21
# 5    12
# 3     9
# 6     6
# 8     2
# 4     1
# Name: count, dtype: int64

# %% [markdown]
# Create function to assign RFM levels

# %%
def assign_rfm_level(x):
    if x >= 7:
        return 'Top'
    elif 4<=x<7:
        return 'Middle'
    else:
        return 'Low'

# %%
rfm_df['rfm_level'] = rfm_df['rfm_score'].map(assign_rfm_level)
rfm_df.head()
# Out:
#       acct_num gender  recency  recency_score  frequency  frequency_score  \
# 0   3843260959      M       26              3        294                3
# 1  20386303916      M      113              1          1                1
# 2  34614744133      M       28              3        101                1
# 3  38399733986      M       25              3        104                2
# 4  99645822249      M       26              3        321                3
#
#    total_amt  monetary_score  rfm_score rfm_level
# 0   20761.41               3          9       Top
# 1       7.02               1          3       Low
# 2    6368.18               1          5    Middle
# 3    7226.88               2          7       Top
# 4   24010.44               3          9       Top

# %%
rfm_df.sort_values('rfm_level', ascending=False)
# Out:
#         acct_num gender  recency  recency_score  frequency  frequency_score  \
# 0     3843260959      M       26              3        294                3
# 52  786000000000      M       27              3        271                3
# 31  471000000000      M       25              3        214                2
# 33  488000000000      M       25              3        295                3
# 34  510000000000      M       26              3        102                2
# ..           ...    ...      ...            ...        ...              ...
# 65  925000000000      M      332              1          1                1
# 6   169000000000      M      142              1          2                1
# 14  229000000000      M      132              1          1                1
# 23  369000000000      M      293              1          1                1
# 25  383000000000      M      210              1          1                1
#
#     total_amt  monetary_score  rfm_score rfm_level
# 0    20761.41               3          9       Top
# 52   21525.18               3          9       Top
# 31   14997.94               2          7       Top
# 33   19221.78               3          9       Top
# 34    7268.69               2          7       Top
# ..        ...             ...        ...       ...
# 65       9.18               1          3       Low
# 6      332.14               1          3       Low
# 14     316.56               1          3       Low
# 23     341.80               1          3       Low
# 25      45.94               1          3       Low
#
# [75 rows x 10 columns]

# %%
a = rfm_df.groupby(['rfm_level','gender'])['total_amt'].mean().to_frame(name='Total').sort_values('Total', ascending = False).reset_index()
a
# Out:
#   rfm_level gender         Total
# 0       Top      M  17883.188667
# 1       Top      F  15220.125000
# 2    Middle      F   7039.023333
# 3    Middle      M   6246.915625
# 4       Low      F    694.360000
# 5       Low      M    205.500000

# %% [markdown]
# Now you have an RFM score to each of your customers, which you can use for targeted strategies
